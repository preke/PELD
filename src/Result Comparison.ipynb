# %%
file_name = 'Emotion_Mode_3_CE_Epochs_50.csv'
import pandas as pd

choice = 'macro'
# choice = 'weighted'

df = pd.read_csv(file_name)
df_plot = df[df['train_label'] == choice + ' avg']


get_ipython().run_line_magic('matplotlib', 'inline')
import numpy as np
import matplotlib.pyplot as plt  

num_epoch = 50
x = range(1, num_epoch + 1)

plt.plot(x,df_plot['train_f1-score'],'ro-',x,df_plot['valid_f1-score'],'g+-',x,df_plot['test_f1-score'],'b^-')

plt.xlabel('row')
plt.ylabel('column')
plt.legend()
plt.show()


end = df_plot['valid_f1-score'].idxmax()
start = end - 8

if choice == 'weighted':
    pass
else:
    start += 1
    end += 1
print('\t'.join([str(i) for i in df['test_f1-score'][start:end+1]]))
df[start:end+1]
# Out:
# No handles with labels found to put in legend.
# 0.1768707482993197	0.0	0.0	0.0	0.5951557093425606	0.0	0.0	0.11028949394884004	0.5559615732079405
#      train_label  train_precision  train_recall  train_f1-score  \
# 9            0.0         0.011511      0.186047        0.021680
# 10           1.0         0.000000      0.000000        0.000000
# 11           2.0         0.000000      0.000000        0.000000
# 12           3.0         0.000000      0.000000        0.000000
# 13           4.0         0.993761      0.426468        0.596815
# 14           5.0         0.000000      0.000000        0.000000
# 15           6.0         0.000000      0.000000        0.000000
# 16     macro avg         0.143610      0.087502        0.088356
# 17  weighted avg         0.985563      0.424426        0.592012
#
#     train_support  valid_precision  valid_recall  valid_f1-score  \
# 9              43         0.207792      0.290909        0.242424
# 10              0         0.000000      0.000000        0.000000
# 11              0         0.000000      0.000000        0.000000
# 12              1         0.000000      0.000000        0.000000
# 13           5229         0.928000      0.436911        0.594110
# 14              0         0.000000      0.000000        0.000000
# 15              0         0.000000      0.000000        0.000000
# 16           5273         0.162256      0.103974        0.119505
# 17           5273         0.860404      0.423208        0.561102
#
#     valid_support  test_precision  test_recall  test_f1-score  test_support
# 9              55        0.151163     0.213115       0.176871            61
# 10              0        0.000000     0.000000       0.000000             0
# 11              0        0.000000     0.000000       0.000000             0
# 12              0        0.000000     0.000000       0.000000             0
# 13            531        0.931408     0.437288       0.595156           590
# 14              0        0.000000     0.000000       0.000000             0
# 15              0        0.000000     0.000000       0.000000             0
# 16            586        0.154653     0.092915       0.110289           651
# 17            586        0.858297     0.416283       0.555962           651
